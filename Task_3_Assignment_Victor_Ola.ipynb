# %% [markdown]
# # Solution to Assignment Task 3
#
# ## Name of Student : Victor Ola
#
# ## Registration No : DS/2025/TC3/244
#
# ##Tutor: Gift Ukpoweh

# %% [markdown]
# ## #Step 1: Import necessary Python Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## #Step 2: Import/Load all the given data to the notebook

# %%
order_details = pd.read_csv('/content/order_details.csv')
orders = pd.read_csv('/content/orders.csv')
pizza_types = pd.read_csv('/content/pizza_types.csv', encoding='latin-1')
pizzas = pd.read_csv('/content/pizzas.csv')

# %% [markdown]
# ## #Step 3: Check data to confirm common column in sheets

# %%
order_details.head()
# Out:
#    order_details_id  order_id       pizza_id  quantity
# 0                 1         1     hawaiian_m         1
# 1                 2         2  classic_dlx_m         1
# 2                 3         2  five_cheese_l         1
# 3                 4         2    ital_supr_l         1
# 4                 5         2     mexicana_m         1

# %%
order_details.shape
# Out:
# (48620, 4)

# %%
orders.head()
# Out:
#    order_id        date      time
# 0         1  2015-01-01  11:38:36
# 1         2  2015-01-01  11:57:40
# 2         3  2015-01-01  12:12:28
# 3         4  2015-01-01  12:16:31
# 4         5  2015-01-01  12:21:30

# %%
orders.shape
# Out:
# (21350, 3)

# %%
pizza_types.head()
# Out:
#   pizza_type_id                          name category  \
# 0       bbq_ckn    The Barbecue Chicken Pizza  Chicken
# 1      cali_ckn  The California Chicken Pizza  Chicken
# 2   ckn_alfredo     The Chicken Alfredo Pizza  Chicken
# 3     ckn_pesto       The Chicken Pesto Pizza  Chicken
# 4    southw_ckn   The Southwest Chicken Pizza  Chicken
#
#                                          ingredients
# 0  Barbecued Chicken, Red Peppers, Green Peppers,...
# 1  Chicken, Artichoke, Spinach, Garlic, Jalapeno ...
# 2  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 3  Chicken, Tomatoes, Red Peppers, Spinach, Garli...
# 4  Chicken, Tomatoes, Red Peppers, Red Onions, Ja...

# %%
pizza_types.shape
# Out:
# (32, 4)

# %%
pizzas.head()
# Out:
#      pizza_id pizza_type_id size  price
# 0   bbq_ckn_s       bbq_ckn    S  12.75
# 1   bbq_ckn_m       bbq_ckn    M  16.75
# 2   bbq_ckn_l       bbq_ckn    L  20.75
# 3  cali_ckn_s      cali_ckn    S  12.75
# 4  cali_ckn_m      cali_ckn    M  16.75

# %%
pizzas.shape
# Out:
# (96, 4)

# %% [markdown]
# ## #Step 4: Check with:
#
# 1. Orders and Order Details file have a common index as: order_id
# 2. Order Details and Pizzas file have a common index as: pizza_id
# 3. Pizzas and pizza_types file have a common index as: pizza_type_id

# %% [markdown]
# ## #Step 5: Having confirmed the common column heading in each data, now use the common column to merge all the tables into one using "Outer Join" merge method

# %%
orders_order_details = pd.merge(orders, order_details, on = "order_id", how = "outer")
orders_order_details_pizzas = pd.merge(orders_order_details, pizzas, on = "pizza_id", how = "outer")
orders_order_details_pizzas_pizza_types = pd.merge(orders_order_details_pizzas, pizza_types, on = "pizza_type_id", how = "outer")
orders_order_details_pizzas_pizza_types
pizza_order_data = orders_order_details_pizzas_pizza_types
pizza_order_data
# Out:
#        order_id        date      time  order_details_id      pizza_id  \
# 0          11.0  2015-01-01  13:02:59              26.0     bbq_ckn_l
# 1          17.0  2015-01-01  13:53:00              43.0     bbq_ckn_l
# 2          27.0  2015-01-01  15:11:17              71.0     bbq_ckn_l
# 3          33.0  2015-01-01  15:54:08              83.0     bbq_ckn_l
# 4          51.0  2015-01-01  18:48:28             123.0     bbq_ckn_l
# ...         ...         ...       ...               ...           ...
# 48620   21251.0  2015-12-30  12:45:20           48406.0  veggie_veg_s
# 48621   21296.0  2015-12-31  15:13:40           48493.0  veggie_veg_s
# 48622   21298.0  2015-12-31  15:35:37           48500.0  veggie_veg_s
# 48623   21299.0  2015-12-31  15:52:16           48503.0  veggie_veg_s
# 48624   21319.0  2015-12-31  18:07:19           48553.0  veggie_veg_s
#
#        quantity pizza_type_id size  price                               name  \
# ...

# %%
pizza_order_data.shape
# Out:
# (48625, 12)

# %%
pizza_order_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48625 entries, 0 to 48624
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          48620 non-null  float64
#  1   date              48620 non-null  object
#  2   time              48620 non-null  object
#  3   order_details_id  48620 non-null  float64
#  4   pizza_id          48625 non-null  object
#  5   quantity          48620 non-null  float64
#  6   pizza_type_id     48625 non-null  object
#  7   size              48625 non-null  object
#  8   price             48625 non-null  float64
#  9   name              48625 non-null  object
#  10  category          48625 non-null  object
#  11  ingredients       48625 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 4.5+ MB

# %% [markdown]
# ## #Step 6: From the info display, all data types are correct except for Date and Time which are in object insted of date time type
#
# Next step: Check the values of the data for ireegularities and null values

# %%
pizza_order_data["date"].value_counts()
# Out:
# date
# 2015-11-26    261
# 2015-11-27    259
# 2015-10-15    258
# 2015-07-04    233
# 2015-07-03    207
#              ...
# 2015-12-27     87
# 2015-11-22     82
# 2015-12-29     77
# 2015-03-22     76
# 2015-12-30     73
# Name: count, Length: 358, dtype: int64

# %% [markdown]
# ## #Step 7: It was observed that no "unknown" or "error" in data. So, now check for null values

# %%
pizza_order_data.isna().sum()
# Out:
# order_id            5
# date                5
# time                5
# order_details_id    5
# pizza_id            0
# quantity            5
# pizza_type_id       0
# size                0
# price               0
# name                0
# category            0
# ingredients         0
# dtype: int64

# %% [markdown]
# ## Step 8: Drop null values for date as missing dates cannot be tracked

# %%
pizza_order_data.dropna(subset = ["date"], inplace = True)

# %%
pizza_order_data.isna().sum()
# Out:
# order_id            0
# date                0
# time                0
# order_details_id    0
# pizza_id            0
# quantity            0
# pizza_type_id       0
# size                0
# price               0
# name                0
# category            0
# ingredients         0
# dtype: int64

# %% [markdown]
# ## #Step 9: Since no null-values exist further, the data is clean for use and can now proceed to answer the questions.
#
# But firstly, save a copy of the clean data

# %%
pizza_order_data.to_csv('cleaned_pizza_order_data.csv')

# %% [markdown]
# ## Question 1: Total Revenue/Sales

# %%
total_sales = (pizza_order_data["quantity"] * pizza_order_data["price"]).sum()
print(f"The total revenue made from pizza sales in this year is: USD'{total_sales:,.2f}'")
# Out:
# The total revenue made from pizza sales in this year is: USD'817,860.05'

# %% [markdown]
# ## Question 2: Total Quantity Sold

# %%
total_quantity_sold = pizza_order_data["quantity"].sum()
print(f"The total quantity of pizzas sold in this year is: '{total_quantity_sold}'")
# Out:
# The total quantity of pizzas sold in this year is: '49574.0'

# %% [markdown]
# ## Question 3: Number of Total Orders

# %%
total_orders = pizza_order_data["order_id"].nunique()
print(f"The total number of pizza orders made is: '{total_orders}'")
# Out:
# The total number of pizza orders made is: '21350'

# %% [markdown]
# ## Question 4: Number of Pizza types Sold

# %%
pizza_types = pizza_order_data["pizza_type_id"].nunique()
print(f"The total number of pizza types sold is: '{pizza_types}'")
# Out:
# The total number of pizza types sold is: '32'

# %% [markdown]
# ## Question 5: Average Price of the Pizzas

# %%
average_price = pizza_order_data["price"].mean()
print(f"The average price of a pizza is: USD'{average_price:,.2f}'")
# Out:
# The average price of a pizza is: USD'16.49'

# %% [markdown]
# ## Question 6: Peak Hours of Sales

# %%
#To compute the data for peak hours and sales quantity
pizza_order_data["time"] = pd.to_datetime(pizza_order_data["time"], format='%H:%M:%S')
peak_hours = pizza_order_data.groupby(pizza_order_data["time"].dt.hour)["quantity"].sum()
peak_sales_hours = peak_hours.sort_values(ascending = False).index[0]
sales_quantity = peak_hours.sort_values(ascending = False).values[0]

#Plot code to show sales of the day and the peak sales hours
plt.plot(peak_hours, color = "red")
plt.title("Sales in a day")
plt.xlabel("Time of the Day")
plt.ylabel("Quantity Sold")

#inserting grid lines in the graph for easy reading of values
plt.grid(True)

plt.show()

print(f"The peak sales hour as shown in the graph is {peak_sales_hours} noon with cummulative sales quantity of: '{sales_quantity}'")
# Out:
# The peak sales hour as shown in the graph is 12 noon with cummulative sales quantity of: '6776.0'

# %% [markdown]
# ## Question 7: Total Sales on Day of Week and Day with Most Sales

# %%
#To compute the data for sales in the week by day and sales quantity
pizza_order_data["date"] = pd.to_datetime(pizza_order_data["date"])
total_sales_day_of_week = pizza_order_data.groupby(pizza_order_data["date"].dt.day_name())["quantity"].sum()
total_sales_day_of_week = total_sales_day_of_week.reindex(["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"])

#day_with_most_sales = total_sales_day_of_week.idxmax()
day_with_most_sales = total_sales_day_of_week.sort_values(ascending = False).index[0]
quantity_week = int(total_sales_day_of_week.sort_values(ascending = False).values[0])

#Plot code to show sales in the week by day
plt.bar(total_sales_day_of_week.index, total_sales_day_of_week.values, color = "green")
plt.title("Total Sales in a Week")
plt.xlabel("Day of the Week")
plt.ylabel("Quantity Sold")
plt.xticks(rotation = 90)

plt.show()

#To print the days of the week and their individual sales
total_sales_day_of_week_string = total_sales_day_of_week.to_string().replace("Name: quantity, dtype: float64", "").strip()
print(f"The total sales on each day of the week is:\n{total_sales_day_of_week_string}")
print(f"\nThe day with the most sales is: '{day_with_most_sales}' at a quantity of: {quantity_week}")
# Out:
# The total sales on each day of the week is:
# date
# Monday       6485.0
# Tuesday      6895.0
# Wednesday    6946.0
# Thursday     7478.0
# Friday       8242.0
# Saturday     7493.0
# Sunday       6035.0
#
# The day with the most sales is: 'Friday' at a quantity of: 8242

# %% [markdown]
# ## Question 8: Top 5 Bestselling Pizzas

# %%
#To compute the data top five bestseeling pizzas and sales quantity
top_five_bestselling_pizzas = pizza_order_data.groupby("pizza_type_id")["quantity"].sum().sort_values(ascending = False).head(5)
top_fifteen_bestselling_pizzas = pizza_order_data.groupby("pizza_type_id")["quantity"].sum().sort_values(ascending = False).head(15)

#Plot code to show the five bestseeling pizzas and sales quantity
plt.bar(top_fifteen_bestselling_pizzas.index, top_fifteen_bestselling_pizzas.values, color = "blue")
plt.title("Top 5 Bestselling Pizzas", fontweight = "bold")
plt.xlabel("Pizza Types")
plt.ylabel("Quantity Sold")
plt.xticks(rotation = 90)

plt.show()

# Convert the Series to a string and remove the unwanted part for printing
top_five_bestselling_pizzas_string = top_five_bestselling_pizzas.to_string().replace("Name: quantity, dtype: float64", "").strip()

#To print the five bestselling pizzas
print(f"The top five best selling pizzas are: \n{top_five_bestselling_pizzas_string}")
# Out:
# The top five best selling pizzas are:
# pizza_type_id
# classic_dlx    2453.0
# bbq_ckn        2432.0
# hawaiian       2422.0
# pepperoni      2418.0
# thai_ckn       2371.0

# %% [markdown]
# ## Question 9: Sales Made in Each Month.

# %%
#To compute the data for monthly sales quantity
pizza_order_data["date"] = pd.to_datetime(pizza_order_data["date"])
sales_in_each_month = pizza_order_data.groupby(pizza_order_data["date"].dt.month_name())["quantity"].sum()
mean_sales_in_year = pizza_order_data.groupby(pizza_order_data["date"].dt.month_name())["quantity"].sum().mean()

#arrange month name for sales in each month in order from january to december
sales_in_each_month = sales_in_each_month.reindex(["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"])

#Plot code to show the monthly sales quantity
plt.bar(sales_in_each_month.index, sales_in_each_month.values, color = "orange")
plt.title("Monthly Sales", fontweight = "bold")
plt.xlabel("Month")
plt.ylabel("Quantity Sold")
plt.xticks(rotation = 90)

plt.show()

# Convert the Series to a string and remove the unwanted part for printing
sales_in_each_month_string = sales_in_each_month.to_string().replace("Name: quantity, dtype: float64", "").strip()

#To print the monthly sales quantity
print(f"The sales made in each month are: \n{sales_in_each_month_string}")
print(f"\nThe average sales made in the year is: \n{mean_sales_in_year}")
# Out:
# The sales made in each month are:
# date
# January      4232.0
# February     3961.0
# March        4261.0
# April        4151.0
# May          4328.0
# June         4107.0
# July         4392.0
# August       4168.0
# September    3890.0
# October      3883.0
# November     4266.0
# December     3935.0
#
# The average sales made in the year is:
# 4131.166666666667

# %% [markdown]
# ## Question 10: Pizza Types Not Doing Well on the menu

# %%
pizza_types_not_doing_well = pizza_order_data.groupby("pizza_type_id")["quantity"].sum().sort_values(ascending = True).head(10)

#Plot code to show the monthly sales quantity
plt.bar(pizza_types_not_doing_well.index, pizza_types_not_doing_well.values, color = "brown")
plt.title("Monthly Sales", fontweight = "bold")
plt.xlabel("Month")
plt.ylabel("Quantity Sold")
plt.xticks(rotation = 90)

plt.show()

# Convert the Series to a string and remove the unwanted part for printing
pizza_types_not_doing_well = pizza_types_not_doing_well.to_string().replace("Name: quantity, dtype: float64", "").strip()

#To print the Pizzas no doing well
print(f"The pizza types not doing well are: \n{pizza_types_not_doing_well}")
# Out:
# The pizza types not doing well are:
# pizza_type_id
# brie_carre      490.0
# mediterraneo    934.0
# calabrese       937.0
# spinach_supr    950.0
# soppressata     961.0
# spin_pesto      970.0
# ckn_pesto       973.0
# ital_veggie     981.0
# ckn_alfredo     987.0
# green_garden    997.0

# %%
#An Alternative way to find the pizza types not doing well provided that the exact benchmark is provided by HQ to be Quantity sold less than 1k.

benchmark_pizza_types_not_doing_well = 1000
pizza_quantity_sum = pizza_order_data.groupby("pizza_type_id")["quantity"].sum()
pizza_types_not_doing_well_benchmark = pizza_quantity_sum[pizza_quantity_sum < benchmark_pizza_types_not_doing_well].sort_values(ascending = True)


# Convert the Series to a string and remove the unwanted part for printing
pizza_types_not_doing_well_benchmark = pizza_types_not_doing_well_benchmark.to_string().replace("Name: quantity, dtype: float64", "").strip()

#To print the Pizzas no doing well
print(f"The pizza types not doing well are: \n{pizza_types_not_doing_well_benchmark}")
# Out:
# The pizza types not doing well are:
# pizza_type_id
# brie_carre      490.0
# mediterraneo    934.0
# calabrese       937.0
# spinach_supr    950.0
# soppressata     961.0
# spin_pesto      970.0
# ckn_pesto       973.0
# ital_veggie     981.0
# ckn_alfredo     987.0
# green_garden    997.0

# %% [markdown]
# ## My Take from the Pizza Data Analysis Done:
#
# *   Promotions can be designed and implemented to boost the sales of the low volume pizza type
#
# *   Sales of Pizza peaked between 12noon to 1pm and 05:00pm to 06:00 pm representing lunch time and closing time respectively. More visibility can be done to make more sales during this hours.
#
# *   There is a steady increase in the sales of Pizza mid week from Tuesday to Saturday. A considerable drop was recorded on Sunday. This trend could be because of other social activities people go for on Sunday or they prefer home-made meals as time to bond with family. Days such as this can be considered for discount to encourage placing orders for Pizzas as against dine-ins.
#
# *   There is a huge difference in the quantity of sales of the top 6 bestselling Pizza types and other types. Customer surveys can be created to get feedbacks on the reason for the low sales of the other pizza type so as to improve on them to get improved sales.
#
# *   Analyses based on the monthly sales showed that the winter months apart from November showed a sales quantity below 4000. Further analysis can be done to find out what can be done in winter months to improve sales. The sales in February also showed below 4000 probably because it has lesser number of days. It could be at par with other months in the year especially in the same quarter.
